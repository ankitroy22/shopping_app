# %%
import clip
import numpy as np
import pandas as pd
import requests
import time
import torch
import warnings

from io import BytesIO
from IPython.display import Image, display
from PIL import Image as PILImage
from tqdm import tqdm

warnings.filterwarnings("ignore")

# %%
# Load CLIP model and preprocess function
device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device = device)
# Out:
# 100%|████████████████████████████████████████| 338M/338M [00:02<00:00, 124MiB/s]

# %%
df = pd.read_csv("/content/sample_data/random_samples.csv")
df.head()
# Out:
#    Unnamed: 0                                     availableSizes  brand.id  \
# 0           0                     [{'scaleId': 0, 'size': 'XS'}]         6
# 1         133  [{'scaleId': 0, 'size': 'M'}, {'scaleId': 0, '...     38206
# 2          26  [{'scaleId': 0, 'size': 'M'}, {'scaleId': 0, '...      5502
# 3         144                                                NaN    120739
# 4          47               [{'scaleId': 0, 'size': 'One Size'}]    825159
#
#          brand.name gender  hasSimilarProducts        id  \
# 0        Paul Smith  women                True  13884060
# 1      Mara Hoffman  women                True  13630929
# 2  Stella McCartney  women                True  13592474
# 3        Jimmy Choo  women                True  14214212
# 4    Andrea Fohrman  women               False  13472532
#
#                                        images.cutOut  \
# 0  https://cdn-images.farfetch-contents.com/13/88...
# 1  https://cdn-images.farfetch-contents.com/13/63...
# 2  https://cdn-images.farfetch-contents.com/13/59...
# 3  https://cdn-images.farfetch-contents.com/14/21...
# 4  https://cdn-images.farfetch-contents.com/13/47...
#
#                                         images.model  isCustomizable  ...  \
# 0  https://cdn-images.farfetch-contents.com/13/88...           False  ...
# 1  https://cdn-images.farfetch-contents.com/13/63...           False  ...
# 2  https://cdn-images.farfetch-contents.com/13/59...           False  ...
# 3  https://cdn-images.farfetch-contents.com/14/21...           False  ...
# 4  https://cdn-images.farfetch-contents.com/13/47...           False  ...
#
#   priceInfo.currencyCode priceInfo.discountLabel  priceInfo.finalPrice  \
# 0                    SGD                 50% Off                   478
# 1                    SGD                     NaN                   629
# 2                    SGD                 50% Off                   948
# 3                    SGD                     NaN                   895
# 4                    SGD                     NaN                  9828
#
#   priceInfo.formattedFinalPrice priceInfo.formattedInitialPrice  \
# 0                          $478                            $955
# 1                          $629                            $629
# 2                          $948                          $1,895
# 3                          $895                            $895
# 4                        $9,828                          $9,828
#
#    priceInfo.initialPrice priceInfo.installmentsLabel priceInfo.isOnSale  \
# 0                     955                         NaN               True
# 1                     629                         NaN              False
# 2                    1895                         NaN               True
# 3                     895                         NaN              False
# 4                    9828                         NaN              False
#
#                                     shortDescription  stockTotal
# 0                      Paul's Photo print midi dress           1
# 1                                 striped maxi dress           3
# 2                       monogram zipped track jacket           3
# 3                                      Love 85 pumps         140
# 4  18kt yellow gold, rock crystal and grey sapphi...           1
#
# [5 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'availableSizes', 'brand.id', 'brand.name', 'gender',
#        'hasSimilarProducts', 'id', 'images.cutOut', 'images.model',
#        'isCustomizable', 'merchandiseLabel', 'merchandiseLabelField',
#        'merchantId', 'priceInfo.currencyCode', 'priceInfo.discountLabel',
#        'priceInfo.finalPrice', 'priceInfo.formattedFinalPrice',
#        'priceInfo.formattedInitialPrice', 'priceInfo.initialPrice',
#        'priceInfo.installmentsLabel', 'priceInfo.isOnSale', 'shortDescription',
#        'stockTotal'],
#       dtype='object')

# %%
df.drop(columns = ['Unnamed: 0', 'availableSizes',
       'hasSimilarProducts', 'images.model',
       'isCustomizable', 'merchandiseLabel', 'merchandiseLabelField',
       'merchantId', 'priceInfo.currencyCode', 'priceInfo.discountLabel',
       'priceInfo.finalPrice', 'priceInfo.formattedFinalPrice',
       'priceInfo.formattedInitialPrice', 'priceInfo.initialPrice',
       'priceInfo.installmentsLabel', 'priceInfo.isOnSale',
       'stockTotal'], inplace = True)

# %%
df.head()
# Out:
#    brand.id        brand.name gender        id  \
# 0         6        Paul Smith  women  13884060
# 1     38206      Mara Hoffman  women  13630929
# 2      5502  Stella McCartney  women  13592474
# 3    120739        Jimmy Choo  women  14214212
# 4    825159    Andrea Fohrman  women  13472532
#
#                                        images.cutOut  \
# 0  https://cdn-images.farfetch-contents.com/13/88...
# 1  https://cdn-images.farfetch-contents.com/13/63...
# 2  https://cdn-images.farfetch-contents.com/13/59...
# 3  https://cdn-images.farfetch-contents.com/14/21...
# 4  https://cdn-images.farfetch-contents.com/13/47...
#
#                                     shortDescription
# 0                      Paul's Photo print midi dress
# 1                                 striped maxi dress
# 2                       monogram zipped track jacket
# 3                                      Love 85 pumps
# 4  18kt yellow gold, rock crystal and grey sapphi...

# %%
df = df.rename(columns={'images.cutOut': 'image', "shortDescription": "title"})
df.head()
# Out:
#    brand.id        brand.name gender        id  \
# 0         6        Paul Smith  women  13884060
# 1     38206      Mara Hoffman  women  13630929
# 2      5502  Stella McCartney  women  13592474
# 3    120739        Jimmy Choo  women  14214212
# 4    825159    Andrea Fohrman  women  13472532
#
#                                                image  \
# 0  https://cdn-images.farfetch-contents.com/13/88...
# 1  https://cdn-images.farfetch-contents.com/13/63...
# 2  https://cdn-images.farfetch-contents.com/13/59...
# 3  https://cdn-images.farfetch-contents.com/14/21...
# 4  https://cdn-images.farfetch-contents.com/13/47...
#
#                                                title
# 0                      Paul's Photo print midi dress
# 1                                 striped maxi dress
# 2                       monogram zipped track jacket
# 3                                      Love 85 pumps
# 4  18kt yellow gold, rock crystal and grey sapphi...

# %%
def preprocess_image(image_url, timeout = 30, retries = 3, backoff = 2):
    attempt = 0
    while attempt < retries:
        try:
            response = requests.get(image_url, timeout = timeout)
            response.raise_for_status()

            image_tensor = preprocess(
                PILImage.open(
                    BytesIO(response.content)
                )
            ).unsqueeze(0).to(device)

            return image_tensor
        except Exception as e:
            print(f"Attempt {attempt + 1} failed: {e}. Retrying in {backoff} seconds...")
            time.sleep(backoff)
            attempt += 1
            backoff *= 2
    print(f"Failed to download image from {image_url} after {retries} attempts.")
    return np.nan

# %%
def preprocess_text(text, max_words = 70):
    words = text.split()
    if len(words) > max_words:
        text = " ".join(words[:max_words])

    text_tensor = clip.tokenize(text).to(device)
    return text_tensor

# %%
def generate_embeddings(row):
    image_tensor = preprocess_image(row["image"]).to('cuda')

    if torch.isnan(image_tensor).any():
        return np.nan, np.nan, np.nan
    text_tensor = preprocess_text(row["title"]).to('cuda')

    with torch.no_grad():
        image_features = model.encode_image(image_tensor)
        text_features = model.encode_text(text_tensor)

        image_features = image_features / image_features.norm(dim=-1, keepdim=True)
        text_features = text_features / text_features.norm(dim=-1, keepdim=True)

        text_vector = text_features.cpu().numpy().flatten()
        image_vector = image_features.cpu().numpy().flatten()
        combined_vector = (text_vector + image_vector) / 2

        return text_vector, image_vector, combined_vector

# %%
tqdm.pandas()

df[["text_vector", "image_vector", "combined_vector"]] = df.progress_apply(
    lambda row: pd.Series(generate_embeddings(row)),
    axis = 1
)
# Out:
#  14%|█▍        | 3/21 [00:20<02:10,  7.23s/it]
# Attempt 1 failed: HTTPSConnectionPool(host='cdn-images.farfetch-contents.com', port=443): Read timed out. (read timeout=30). Retrying in 2 seconds...
#  19%|█▉        | 4/21 [01:02<05:39, 19.97s/it]
# Attempt 1 failed: HTTPSConnectionPool(host='cdn-images.farfetch-contents.com', port=443): Read timed out. (read timeout=30). Retrying in 2 seconds...
#  24%|██▍       | 5/21 [01:44<07:24, 27.76s/it]
# Attempt 1 failed: HTTPSConnectionPool(host='cdn-images.farfetch-contents.com', port=443): Read timed out. (read timeout=30). Retrying in 2 seconds...
# 100%|██████████| 21/21 [05:02<00:00, 14.41s/it]

# %%
df
# Out:
#     brand.id             brand.name  gender        id  \
# 0          6             Paul Smith   women  13884060
# 1      38206           Mara Hoffman   women  13630929
# 2       5502       Stella McCartney   women  13592474
# 3     120739             Jimmy Choo   women  14214212
# 4     825159         Andrea Fohrman   women  13472532
# 5     842573          Talbot Runhof   women  13254961
# 6      77463                  Dusan   women  13819532
# 7    2638322            Mira Mikati   women  13919087
# 8       3440        Dolce & Gabbana   women  12543581
# 9      25354                  Gucci   women  12952115
# 10      4224                  Marni   women  11282067
# 11     25370  Diane von Furstenberg   women  13569411
# 12   2178713            Sener Besim  unisex  12079203
# 13    330188        Fabiana Filippi   women  13144605
# 14   3344622          Zac Zac Posen   women  14099012
# 15     18286             Tory Burch   women  14208234
# 16   2049709         Mansur Gavriel   women  13254287
# 17      4117           Sonia Rykiel   women  13199217
# 18    211274        Manning Cartell   women  13361481
# 19     90739     Brunello Cucinelli   women  14119886
# 20   6523816          Richard Quinn   women  14259256
#
#                                                 image  \
# 0   https://cdn-images.farfetch-contents.com/13/88...
# 1   https://cdn-images.farfetch-contents.com/13/63...
# 2   https://cdn-images.farfetch-contents.com/13/59...
# 3   https://cdn-images.farfetch-contents.com/14/21...
# 4   https://cdn-images.farfetch-contents.com/13/47...
# 5   https://cdn-images.farfetch-contents.com/13/25...
# 6   https://cdn-images.farfetch-contents.com/13/81...
# 7   https://cdn-images.farfetch-contents.com/13/91...
# 8   https://cdn-images.farfetch-contents.com/12/54...
# 9   https://cdn-images.farfetch-contents.com/12/95...
# 10  https://cdn-images.farfetch-contents.com/11/28...
# 11  https://cdn-images.farfetch-contents.com/13/56...
# 12  https://cdn-images.farfetch-contents.com/12/07...
# 13  https://cdn-images.farfetch-contents.com/13/14...
# 14  https://cdn-images.farfetch-contents.com/14/09...
# 15  https://cdn-images.farfetch-contents.com/14/20...
# 16  https://cdn-images.farfetch-contents.com/13/25...
# 17  https://cdn-images.farfetch-contents.com/13/19...
# 18  https://cdn-images.farfetch-contents.com/13/36...
# 19  https://cdn-images.farfetch-contents.com/14/11...
# 20  https://cdn-images.farfetch-contents.com/14/25...
#
#                                                 title  \
# 0                       Paul's Photo print midi dress
# 1                                  striped maxi dress
# 2                        monogram zipped track jacket
# 3                                       Love 85 pumps
# 4   18kt yellow gold, rock crystal and grey sapphi...
# 5                       floral embellished long dress
# 6                                   front button coat
# 7                               Just Chilling T-shirt
# 8                        printed iPhone 6/7 Plus case
# 9                       sequin stripes track trousers
# 10                        Melodia Flower print dress
# 11                              cut-out detail jumper
# 12                       S3 Modern aviator sunglasses
# 13                     side stripe straight trousers
# 14                         Floral Bouquet Shopper bag
# 15                                  Kira shoulder bag
# 16                               Circle crossbody bag
# 17                            clip-on crystal earring
# 18                   printed double breasted blazer a
# 19                             double-band waist belt
# 20                                      floral tights
#
#                                           text_vector  \
# 0   [0.01471, -0.04083, -0.00892, 0.03815, -0.0433...
# 1   [-0.01917, 0.00584, -0.0394, 0.007027, -0.0200...
# 2   [-0.029, 0.0536, 0.0422, 0.01233, -0.004227, 0...
# 3   [-0.01857, -0.0182, 0.0088, -0.00549, -0.04932...
# 4   [0.02115, -0.0365, -0.02979, 0.013374, 0.01816...
# 5   [0.04004, -0.010025, -0.01449, 0.10443, -0.033...
# 6   [-0.0355, 0.03207, -0.02606, 0.004368, 0.00369...
# 7   [0.02293, 0.02837, -0.03293, 0.02602, -0.0392,...
# 8   [-0.00844, 0.006577, -0.04694, 0.05237, 0.0218...
# 9   [-0.00987, 0.01214, -0.06793, -2.915e-05, -0.0...
# 10  [0.02434, -0.05273, 0.02975, 0.0439, -0.03796,...
# 11  [-0.00994, 0.00255, -0.04138, 0.00511, -0.0471...
# 12  [0.0229, 0.010506, 0.01675, 0.03534, -0.06055,...
# 13  [-0.03177, 0.01055, -0.03278, 0.002071, -0.044...
# 14  [0.04605, -0.03284, -0.03412, 0.02446, -0.0094...
# 15  [0.03088, 0.001159, -0.05444, 0.02234, -0.0252...
# 16  [0.00743, -0.00426, -0.0426, 0.0713, -0.02318,...
# 17  [-0.03806, -0.0451, 0.03223, -0.00464, 0.00201...
# 18  [-0.003206, 0.001799, -0.0199, -0.03009, 0.012...
# 19  [-0.0157, 0.00855, -0.00772, 0.01631, -0.0515,...
# 20  [0.02205, -0.002161, -0.03323, 0.0392, -0.0408...
#
#                                          image_vector  \
# 0   [0.01084, 0.01301, -0.002697, -0.02037, 0.0164...
# 1   [0.02278, 0.02046, -0.0002176, 0.03137, -0.004...
# 2   [-0.004604, 0.01595, 0.018, -0.00953, 0.0133, ...
# 3   [-0.02551, -0.03333, 0.03232, 0.01557, -0.0270...
# 4   [-0.01415, -0.05432, 0.02159, -0.02385, -0.019...
# 5   [0.00949, -0.010155, 0.01008, 0.04245, -0.0341...
# 6   [-0.006107, 0.0134, 0.00292, 0.0311, 0.0185, 0...
# 7   [0.02617, 0.00284, 0.01397, 0.015564, 0.000779...
# 8   [0.02592, -0.01515, -0.0296, -0.02725, 0.00012...
# 9   [0.02394, 0.001843, -0.0201, 0.02277, -0.04642...
# 10  [0.01804, 0.05832, -0.0061, 0.03848, -0.01519,...
# 11  [0.0009, 0.03787, 0.02377, 0.002197, 0.012764,...
# 12  [0.00884, -0.01538, 0.04187, 0.0054, -0.02467,...
# 13  [0.001725, -0.00058, -0.011734, 0.04575, -0.03...
# 14  [0.00859, 0.0146, 0.007565, 0.03876, 0.00478, ...
# 15  [0.001166, -0.03192, 0.0009017, 0.006123, 0.00...
# 16  [-0.006313, -0.00651, -0.014786, 0.04218, 0.00...
# 17  [-0.02173, -0.0009418, 0.004158, -0.05728, -0....
# 18  [0.012886, 0.02649, 0.01814, -0.007645, 0.0189...
# 19  [0.00868, -0.0257, 0.004623, -0.01259, 0.00116...
# 20  [0.03485, 0.0005407, 0.00944, 0.015, -0.01695,...
#
#                                       combined_vector
# 0   [0.01277, -0.013916, -0.005806, 0.00889, -0.01...
# 1   [0.001808, 0.01315, -0.0198, 0.0192, -0.01208,...
# 2   [-0.0168, 0.03476, 0.0301, 0.0014, 0.004536, 0...
# 3   [-0.02203, -0.02576, 0.02055, 0.005043, -0.038...
# 4   [0.003498, -0.0454, -0.004097, -0.005238, -0.0...
# 5   [0.02477, -0.010086, -0.002205, 0.0734, -0.033...
# 6   [-0.0208, 0.02274, -0.01157, 0.01773, 0.01109,...
# 7   [0.02455, 0.0156, -0.009476, 0.02078, -0.01921...
# 8   [0.00874, -0.004288, -0.03827, 0.01256, 0.0109...
# 9   [0.007034, 0.006992, -0.044, 0.01137, -0.04587...
# 10  [0.02118, 0.002792, 0.011826, 0.0412, -0.02658...
# 11  [-0.00452, 0.02022, -0.008804, 0.003654, -0.01...
# 12  [0.01587, -0.002438, 0.02931, 0.02037, -0.0426...
# 13  [-0.01502, 0.004986, -0.02225, 0.02391, -0.040...
# 14  [0.02731, -0.00912, -0.013275, 0.03162, -0.002...
# 15  [0.01602, -0.01538, -0.02676, 0.01423, -0.0100...
# 16  [0.000559, -0.005386, -0.02869, 0.05673, -0.00...
# 17  [-0.02989, -0.02303, 0.01819, -0.03096, -0.003...
# 18  [0.00484, 0.014145, -0.0008774, -0.01886, 0.01...
# 19  [-0.00351, -0.008575, -0.001549, 0.001862, -0....
# 20  [0.02844, -0.00081, -0.0119, 0.0271, -0.0289, ...

# %%
import json

df['text_vector'] = df['text_vector'].apply(lambda x: [float(i) for i in x])
df['image_vector'] = df['image_vector'].apply(lambda x: [float(i) for i in x])
df['combined_vector'] = df['combined_vector'].apply(lambda x: [float(i) for i in x])

df.to_json('output.json', orient='records')

# %%
import sqlite3
import json

conn = sqlite3.connect('mydatabase.db')
cursor = conn.cursor()

cursor.execute('''
    CREATE TABLE IF NOT EXISTS image_data (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        data TEXT
    )
''')

with open('output.json', 'r') as file:
    data = json.load(file)

for record in data:
    json_record = json.dumps(record)
    cursor.execute("INSERT INTO image_data (data) VALUES (?)", (json_record,))

conn.commit()
conn.close()
